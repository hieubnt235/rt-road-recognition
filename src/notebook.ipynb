# %%
import numpy as np

from datasets.camvid import CamVid
import albumentations as A

transform = A.Compose([A.HorizontalFlip(p=0.5), ])
ds = CamVid(augmentation=transform)
ds.show_pairs(4, figsize=(15, 10), images_pairs=[ds[100],ds[235]])

# %%
from torch.utils.data import DataLoader
train_dl = DataLoader(ds,batch_size=2)

# %%
data = next(iter(train_dl))

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 adta
#
# NameError: name 'adta' is not defined

# %%
from datasets.camvid import CamVid
ds = CamVid()

# %%
t.shape
# Out:
# (720, 960, 3)

# %%
a = np.zeros((1,2))
b = np.zeros((1,2))
b[0,0] = 1
c = a==b
c.all()
# Out:
# np.False_

# %%
import torch
a = torch.zeros((5,20,20,3))
a.shape[3]
# Out:
# 3

# %%
a.permute(0,3,1,2).shape
# Out:
# torch.Size([5, 3, 20, 20])

# %%
a.shape[]

# %%
import numpy as np
arr = np.array([1,2,3],dtype=np.uint8)
t = torch.from_numpy(arr)
torch.uint8 == np.uint8
arr.shape
# Out:
# (3,)

# %%
import segmentation_models_pytorch as smp
pre_param = smp.encoders.get_preprocessing_params("resnet34")

# %%
a.shape[1:3] == (20,20)
# Out:
# True

# %%
a.unsqueeze(0).shape
# Out:
# torch.Size([1, 5, 20, 20, 3])

# %%
model = smp.DeepLabV3Plus(classes=3)
print(model.training)
model.eval()
inp = torch.zeros((3,320,320))
print(inp.shape)
# conv = torch.nn.Conv2d(3,5,5)
# out = conv(inp)
# out.shape
# print(inp.shape)
out = model(inp)
print(out.shape)
# Out:
# True
# torch.Size([3, 320, 320])
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[48], line 10
#       5 print(inp.shape)
#       6 # conv = torch.nn.Conv2d(3,5,5)
#       7 # out = conv(inp)
#       8 # out.shape
#       9 # print(inp.shape)
# ---> 10 out = model(inp)
#      11 print(out.shape)
#
# File ~/Workspace/AI-ws/.venv/lib/python3.13/site-packages/torch/nn/modules/module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File ~/Workspace/AI-ws/.venv/lib/python3.13/site-packages/torch/nn/modules/module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
# ...

# %%
a = a.to(torch.uint8)
print(a.dtype)
isinstance(a, torch.ByteTensor)
# Out:
# torch.uint8
# True

# %%
a.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 a.shape
#
# NameError: name 'a' is not defined
